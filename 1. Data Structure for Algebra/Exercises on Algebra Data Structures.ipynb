# %% [markdown]
# Nomor 1

# %%
import numpy as np

# %% [markdown]
# Selesaikan soal (transpose) berikut
# ![s-blob-v1-IMAGE-h0K2xWLHCDw.png](data:image/png;base64,...)

# %%
x = np.array([[25], [2], [-3], [-23]])
print("Vektor x:\n", x)
x_t = x.T
print("Transpos dari matrik x: ",x_t)
# Out:
# Vektor x:
#  [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
# Transpos dari matrik x:  [[ 25   2  -3 -23]]
