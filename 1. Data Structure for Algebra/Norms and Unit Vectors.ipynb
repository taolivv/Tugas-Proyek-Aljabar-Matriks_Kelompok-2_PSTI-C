# %% [markdown]
# Nomor 1

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([[1], [2], [3]])
print("vektor x:\n", x)
# Out:
# vektor x:
#  [[1]
#  [2]
#  [3]]

# %%
# hitung nilai L2 norm dari vector x
print("nilai L2 norm dari vektor x:", (1**2 + 2**2 + 3**2)**(1/2))
# Out:
# nilai L2 norm dari vektor x: 3.7416573867739413

# %% [markdown]
# Nomor 2

# %%
# buat vector v dengan elemen (3,4)
v = np.array([3, 4])
print("Vektor v:",v)
# Out:
# Vektor v: [3 4]

# %%
# hitung nilai L2 norm dari vector v
norm = np.linalg.norm(v)
print("Panjang vektor v:", norm)
# Out:
# Panjang vektor v: 5.0

# %%
# tampilkan unit vector dari vector v
unit_v = v / norm
print("Unit vector v:", unit_v)
# Out:
# Unit vector v: [0.6 0.8]

# %%
# hitung panjang unit vector dari vector v
print("Panjang unit vector v:", np.linalg.norm(unit_v))
# Out:
# Panjang unit vector v: 1.0
