# %% [markdown]
# Nomor 1

# %%
import numpy as np
import torch as pt
import tensorflow as tf

# %%
# buat vector x dan y dengan ukuran 1x3 menggunakan numpy
x = np.array([10, 20, 30])
y = np.array([15, 30, 45])
print("Vector x :", x)
print("Vector y :", y)
# Out:
# Vector x : [10 20 30]
# Vector y : [15 30 45]

# %%
# buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch
x_pt = pt.tensor([10, 20, 30])
y_pt = pt.tensor([15, 30, 45])
print("Vector x_pt :", x_pt)
print("Vector y_pt :", y_pt)
# Out:
# Vector x_pt : tensor([10, 20, 30])
# Vector y_pt : tensor([15, 30, 45])

# %%
# buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow
x_tf = tf.Variable([10, 20, 30])
y_tf = tf.Variable([15, 30, 45])
print("Vector x_tf :", x_tf)
print("Vector y_tf :", y_tf)
# Out:
# Vector x_tf : <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 20, 30], dtype=int32)>
# Vector y_tf : <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([15, 30, 45], dtype=int32)>

# %% [markdown]
# Nomor 2

# %%
# hitung perkalian dot product antara vector x dan vector y
np.dot(x, y)
# Out:
# np.int64(2100)

# %%
# hitung perkalian dot product antara vector x_pt dan vector y_pt
pt.dot(x_pt, y_pt)
# Out:
# tensor(2100)

# %%
# hitung perkalian dot product antara vector x_tf dan vector y_tf
tf.tensordot(x_tf, y_tf, axes=1)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2100>

# %% [markdown]
# Nomor 3, lakukan perhitungan excercise menggunakan collab

# %% [markdown]
# ![s-blob-v1-IMAGE-ukGVRQC_RN0.png](data:image/png;base64,...)

# %%
# 1 - Apa Transpose dari matrix Y?
Y = np.array([[42, 4, 7, 99], [-99, -3, 17, 22]])
print("Matrix Y : \n", Y)
Y_t = Y.T
print("\nMatrix Y Transpose : \n", Y_t)
# Out:
# Matrix Y :
#  [[ 42   4   7  99]
#  [-99  -3  17  22]]
#
# Matrix Y Transpose :
#  [[ 42 -99]
#  [  4  -3]
#  [  7  17]
#  [ 99  22]]

# %%
# 2 - Apa Hasil Hadamard Product antara matrix A dan B
A = np.array([[25, 10], [-2, 1]])
B = np.array([[-1, 7], [10, 8]])
print("Matrix A : \n", A)
print("\nMatrix B : \n", B)
hadamard_product = A * B
print("\nHadamard Product antara A dan B : \n", hadamard_product)
# Out:
# Matrix A :
#  [[25 10]
#  [-2  1]]
#
# Matrix B :
#  [[-1  7]
#  [10  8]]
#
# Hadamard Product antara A dan B :
#  [[-25  70]
#  [-20   8]]

# %%
# 3 - Apa hasil dot product dari tensor w dan x
w = np.array([-1, 2, -2])
x = np.array([5, 10, 0])
print(np.dot(w, x))
# Out:
# 15
